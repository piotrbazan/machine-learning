# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile('cifar-10-python.tar.gz'):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            'cifar-10-python.tar.gz',
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open('cifar-10-python.tar.gz') as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np
import matplotlib.pyplot as plt

# Explore the dataset
batch_id = 1
sample_id = 10
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 1:
# Samples: 10000
# Label Counts: {0: 1005, 1: 974, 2: 1032, 3: 1016, 4: 999, 5: 937, 6: 1030, 7: 1001, 8: 1025, 9: 981}
# First 20 Labels: [6, 9, 9, 4, 1, 1, 2, 7, 8, 3, 4, 7, 7, 2, 9, 9, 9, 3, 2, 6]
#
# Example of Image 10:
# Image - Min Value: 24 Max Value: 130
# Image - Shape: (32, 32, 3)
# Label - Label Id: 4 Name: deer

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    # TODO: Implement Function
    return x/256.


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# **Hint:**
#
# Look into LabelBinarizer in the preprocessing module of sklearn.

# %%
def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    rows = len(x)
    result = np.zeros((rows, 10), dtype=np.int)
    result[range(rows), x] = 1
    return result


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a batch of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, shape=(None, *image_shape), name='x')


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.int8, shape=(None, n_classes), name='y')


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, name='keep_prob')


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.
#
# ** Hint: **
#
# When unpacking values as an argument in Python, look into the [unpacking](https://docs.python.org/3/tutorial/controlflow.html#unpacking-argument-lists) operator.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    stddev = 0.01
    depth = x_tensor.get_shape().as_list()[3]
    w = tf.Variable(tf.truncated_normal([*conv_ksize, depth, conv_num_outputs], stddev=stddev))
    b = tf.Variable(tf.truncated_normal([conv_num_outputs], stddev=stddev))
    conv = tf.nn.conv2d(x_tensor, w, [1, *conv_strides, 1], padding='SAME')
    conv = tf.nn.relu(conv + b)    
    conv_maxpool = tf.nn.max_pool(conv, [1, *pool_ksize, 1] , [1, *pool_strides, 1], padding='SAME')
    print('Layer shape:', conv.get_shape().as_list())
    print('Layer shape after pooling:', conv_maxpool.get_shape().as_list())
    return conv_maxpool


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Layer shape: [None, 8, 8, 10]
# Layer shape after pooling: [None, 4, 4, 10]
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # TODO: Implement Function
    s = x_tensor.get_shape().as_list()
    return tf.reshape(x_tensor, [tf.shape(x_tensor)[0], s[1] * s[2] * s[3]])


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    s = x_tensor.get_shape().as_list()
    w = tf.Variable(tf.truncated_normal([s[1], num_outputs]))
    b = tf.Variable(tf.truncated_normal([num_outputs]))
    fc = tf.matmul(x_tensor, w) + b
    fc = tf.nn.relu(fc)
    return fc


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    s = x_tensor.get_shape().as_list()
    w = tf.Variable(tf.truncated_normal([s[1], num_outputs]))
    b = tf.Variable(tf.truncated_normal([num_outputs]))
    o = tf.matmul(x_tensor, w) + b
    return o


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    conv1 = conv2d_maxpool(x,     64, (3,3), (1,1), (2,2), (2,2))
    conv2 = conv2d_maxpool(conv1, 128, (3,3), (1,1), (2,2), (2,2))        
    conv3 = conv2d_maxpool(conv2, 256, (3,3), (1,1), (2,2), (2,2))        
    
    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    #   flatten(x_tensor)
    f = flatten(conv3)

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #   fully_conn(x_tensor, num_outputs)
    fc = fully_conn(f, 4096)
    fc = tf.nn.dropout(fc, keep_prob, name='fc')
    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   output(x_tensor, num_outputs)
    o = output(fc, 10)
    
    # TODO: return output
    return o


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# Layer shape: [None, 32, 32, 64]
# Layer shape after pooling: [None, 16, 16, 64]
# Layer shape: [None, 16, 16, 128]
# Layer shape after pooling: [None, 8, 8, 128]
# Layer shape: [None, 8, 8, 256]
# Layer shape after pooling: [None, 4, 4, 256]
# Layer shape: [None, 32, 32, 64]
# Layer shape after pooling: [None, 16, 16, 64]
# Layer shape: [None, 16, 16, 128]
# Layer shape after pooling: [None, 8, 8, 128]
# Layer shape: [None, 8, 8, 256]
# Layer shape after pooling: [None, 4, 4, 256]
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    session.run(optimizer, feed_dict={x: feature_batch, y:label_batch, keep_prob: keep_probability})

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    c = session.run(cost, feed_dict={x: feature_batch, y:label_batch, keep_prob: 1.})
    acc = session.run(accuracy, feed_dict={x: valid_features, y:valid_labels, keep_prob: 1.})
    print('Loss=%.3f accuracy=%.1f' % (c, acc * 100.))
    return c, acc

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 50
batch_size = 512
keep_probability = .6

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
hist = []
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')        
        hist.append(print_stats(sess, batch_features, batch_labels, cost, accuracy))
        
        
    hist = np.array(hist)
    plt.figure(figsize=(14,4))
    plt.subplot(121)
    plt.plot(hist[:,0])
    plt.ylabel('Loss')    
    plt.xlabel('Epoch')
    plt.subplot(122)
    plt.plot(hist[:,1])
    plt.ylabel('Accuracy')    
    plt.xlabel('Epoch')
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  Loss=3.767 accuracy=13.0
# Epoch  2, CIFAR-10 Batch 1:  Loss=6.378 accuracy=20.9
# Epoch  3, CIFAR-10 Batch 1:  Loss=10.361 accuracy=21.5
# Epoch  4, CIFAR-10 Batch 1:  Loss=8.466 accuracy=27.8
# Epoch  5, CIFAR-10 Batch 1:  Loss=9.454 accuracy=29.6
# Epoch  6, CIFAR-10 Batch 1:  Loss=8.705 accuracy=32.2
# Epoch  7, CIFAR-10 Batch 1:  Loss=8.235 accuracy=34.1
# Epoch  8, CIFAR-10 Batch 1:  Loss=7.597 accuracy=37.1
# Epoch  9, CIFAR-10 Batch 1:  Loss=7.152 accuracy=38.2
# Epoch 10, CIFAR-10 Batch 1:  Loss=5.862 accuracy=35.9
# Epoch 11, CIFAR-10 Batch 1:  Loss=4.873 accuracy=40.0
# Epoch 12, CIFAR-10 Batch 1:  Loss=4.072 accuracy=38.8
# Epoch 13, CIFAR-10 Batch 1:  Loss=2.906 accuracy=38.3
# Epoch 14, CIFAR-10 Batch 1:  Loss=2.195 accuracy=40.2
# Epoch 15, CIFAR-10 Batch 1:  Loss=1.664 accuracy=41.6
# Epoch 16, CIFAR-10 Batch 1:  Loss=1.596 accuracy=42.4
# Epoch 17, CIFAR-10 Batch 1:  Loss=1.594 accuracy=43.0
# Epoch 18, CIFAR-10 Batch 1:  Loss=1.511 accuracy=45.2
# Epoch 19, CIFAR-10 Batch 1:  Loss=1.474 accuracy=45.9
# Epoch 20, CIFAR-10 Batch 1:  Loss=1.459 accuracy=45.6
# Epoch 21, CIFAR-10 Batch 1:  Loss=1.479 accuracy=45.2
# Epoch 22, CIFAR-10 Batch 1:  Loss=1.437 accuracy=46.2
# Epoch 23, CIFAR-10 Batch 1:  Loss=1.428 accuracy=45.9
# Epoch 24, CIFAR-10 Batch 1:  Loss=1.398 accuracy=47.3
# Epoch 25, CIFAR-10 Batch 1:  Loss=1.370 accuracy=47.4
# Epoch 26, CIFAR-10 Batch 1:  Loss=1.403 accuracy=47.1
# Epoch 27, CIFAR-10 Batch 1:  Loss=1.355 accuracy=47.3
# Epoch 28, CIFAR-10 Batch 1:  Loss=1.328 accuracy=48.9
# Epoch 29, CIFAR-10 Batch 1:  Loss=1.297 accuracy=48.5
# Epoch 30, CIFAR-10 Batch 1:  Loss=1.297 accuracy=48.6
# Epoch 31, CIFAR-10 Batch 1:  Loss=1.296 accuracy=48.5
# Epoch 32, CIFAR-10 Batch 1:  Loss=1.290 accuracy=49.9
# Epoch 33, CIFAR-10 Batch 1:  Loss=1.308 accuracy=49.5
# Epoch 34, CIFAR-10 Batch 1:  Loss=1.286 accuracy=49.0
# Epoch 35, CIFAR-10 Batch 1:  Loss=1.255 accuracy=50.0
# Epoch 36, CIFAR-10 Batch 1:  Loss=1.232 accuracy=50.1
# Epoch 37, CIFAR-10 Batch 1:  Loss=1.242 accuracy=49.5
# Epoch 38, CIFAR-10 Batch 1:  Loss=1.235 accuracy=50.0
# Epoch 39, CIFAR-10 Batch 1:  Loss=1.208 accuracy=51.2
# Epoch 40, CIFAR-10 Batch 1:  Loss=1.210 accuracy=51.6
# Epoch 41, CIFAR-10 Batch 1:  Loss=1.216 accuracy=49.9
# Epoch 42, CIFAR-10 Batch 1:  Loss=1.199 accuracy=50.3
# Epoch 43, CIFAR-10 Batch 1:  Loss=1.175 accuracy=50.9
# Epoch 44, CIFAR-10 Batch 1:  Loss=1.149 accuracy=52.1
# Epoch 45, CIFAR-10 Batch 1:  Loss=1.163 accuracy=52.3
# Epoch 46, CIFAR-10 Batch 1:  Loss=1.153 accuracy=52.4
# Epoch 47, CIFAR-10 Batch 1:  Loss=1.141 accuracy=50.9
# Epoch 48, CIFAR-10 Batch 1:  Loss=1.149 accuracy=51.8
# Epoch 49, CIFAR-10 Batch 1:  Loss=1.122 accuracy=51.8
# Epoch 50, CIFAR-10 Batch 1:  Loss=1.110 accuracy=51.8

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
hist = []
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')        
        hist.append(print_stats(sess, batch_features, batch_labels, cost, accuracy))
        
        
    hist = np.array(hist)
    plt.figure(figsize=(14,4))
    plt.subplot(121)
    plt.plot(hist[:,0])
    plt.ylabel('Loss')    
    plt.xlabel('Epoch')
    plt.subplot(122)
    plt.plot(hist[:,1])
    plt.ylabel('Accuracy')    
    plt.xlabel('Epoch')
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  Loss=5.373 accuracy=15.6
# Epoch  2, CIFAR-10 Batch 1:  Loss=9.306 accuracy=24.5
# Epoch  3, CIFAR-10 Batch 1:  Loss=8.738 accuracy=28.2
# Epoch  4, CIFAR-10 Batch 1:  Loss=12.192 accuracy=29.9
# Epoch  5, CIFAR-10 Batch 1:  Loss=8.679 accuracy=37.8
# Epoch  6, CIFAR-10 Batch 1:  Loss=8.944 accuracy=39.7
# Epoch  7, CIFAR-10 Batch 1:  Loss=7.285 accuracy=41.6
# Epoch  8, CIFAR-10 Batch 1:  Loss=6.228 accuracy=41.1
# Epoch  9, CIFAR-10 Batch 1:  Loss=4.566 accuracy=43.5
# Epoch 10, CIFAR-10 Batch 1:  Loss=3.635 accuracy=44.1
# Epoch 11, CIFAR-10 Batch 1:  Loss=2.733 accuracy=41.8
# Epoch 12, CIFAR-10 Batch 1:  Loss=1.728 accuracy=44.7
# Epoch 13, CIFAR-10 Batch 1:  Loss=1.397 accuracy=46.8
# Epoch 14, CIFAR-10 Batch 1:  Loss=1.332 accuracy=48.2
# Epoch 15, CIFAR-10 Batch 1:  Loss=1.306 accuracy=49.2
# Epoch 16, CIFAR-10 Batch 1:  Loss=1.282 accuracy=49.9
# Epoch 17, CIFAR-10 Batch 1:  Loss=1.256 accuracy=51.3
# Epoch 18, CIFAR-10 Batch 1:  Loss=1.229 accuracy=50.9
# Epoch 19, CIFAR-10 Batch 1:  Loss=1.197 accuracy=51.2
# Epoch 20, CIFAR-10 Batch 1:  Loss=1.173 accuracy=51.6
# Epoch 21, CIFAR-10 Batch 1:  Loss=1.169 accuracy=52.1
# Epoch 22, CIFAR-10 Batch 1:  Loss=1.154 accuracy=52.6
# Epoch 23, CIFAR-10 Batch 1:  Loss=1.128 accuracy=52.3
# Epoch 24, CIFAR-10 Batch 1:  Loss=1.100 accuracy=52.9
# Epoch 25, CIFAR-10 Batch 1:  Loss=1.108 accuracy=52.7
# Epoch 26, CIFAR-10 Batch 1:  Loss=1.072 accuracy=52.8
# Epoch 27, CIFAR-10 Batch 1:  Loss=1.075 accuracy=53.0
# Epoch 28, CIFAR-10 Batch 1:  Loss=1.057 accuracy=53.8
# Epoch 29, CIFAR-10 Batch 1:  Loss=1.017 accuracy=54.0
# Epoch 30, CIFAR-10 Batch 1:  Loss=1.013 accuracy=53.8
# Epoch 31, CIFAR-10 Batch 1:  Loss=1.021 accuracy=54.3
# Epoch 32, CIFAR-10 Batch 1:  Loss=0.990 accuracy=53.7
# Epoch 33, CIFAR-10 Batch 1:  Loss=0.964 accuracy=54.3
# Epoch 34, CIFAR-10 Batch 1:  Loss=0.943 accuracy=54.0
# Epoch 35, CIFAR-10 Batch 1:  Loss=0.937 accuracy=54.6
# Epoch 36, CIFAR-10 Batch 1:  Loss=0.919 accuracy=54.3
# Epoch 37, CIFAR-10 Batch 1:  Loss=0.938 accuracy=55.1
# Epoch 38, CIFAR-10 Batch 1:  Loss=0.899 accuracy=55.5
# Epoch 39, CIFAR-10 Batch 1:  Loss=0.897 accuracy=55.2
# Epoch 40, CIFAR-10 Batch 1:  Loss=0.854 accuracy=55.6
# Epoch 41, CIFAR-10 Batch 1:  Loss=0.867 accuracy=56.2
# Epoch 42, CIFAR-10 Batch 1:  Loss=0.850 accuracy=55.4
# Epoch 43, CIFAR-10 Batch 1:  Loss=0.846 accuracy=55.5
# Epoch 44, CIFAR-10 Batch 1:  Loss=0.831 accuracy=56.0
# Epoch 45, CIFAR-10 Batch 1:  Loss=0.818 accuracy=56.0
# Epoch 46, CIFAR-10 Batch 1:  Loss=0.816 accuracy=55.8
# Epoch 47, CIFAR-10 Batch 1:  Loss=0.735 accuracy=57.0
# Epoch 48, CIFAR-10 Batch 1:  Loss=0.742 accuracy=56.4
# Epoch 49, CIFAR-10 Batch 1:  Loss=0.768 accuracy=55.7
# Epoch 50, CIFAR-10 Batch 1:  Loss=0.746 accuracy=56.6

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
hist = []
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')            
            hist.append(print_stats(sess, batch_features, batch_labels, cost, accuracy))
        
    hist = np.array(hist)
    plt.figure(figsize=(14,4))
    plt.subplot(121)
    plt.plot(hist[:,0])
    plt.ylabel('Loss')    
    plt.xlabel('Epoch')
    plt.subplot(122)
    plt.plot(hist[:,1])
    plt.ylabel('Accuracy')    
    plt.xlabel('Epoch')
        
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  Loss=5.495 accuracy=15.6
# Epoch  1, CIFAR-10 Batch 2:  Loss=8.510 accuracy=22.6
# Epoch  1, CIFAR-10 Batch 3:  Loss=10.312 accuracy=23.5
# Epoch  1, CIFAR-10 Batch 4:  Loss=7.932 accuracy=30.9
# Epoch  1, CIFAR-10 Batch 5:  Loss=7.110 accuracy=34.0
# Epoch  2, CIFAR-10 Batch 1:  Loss=8.258 accuracy=37.2
# Epoch  2, CIFAR-10 Batch 2:  Loss=5.256 accuracy=41.3
# Epoch  2, CIFAR-10 Batch 3:  Loss=4.342 accuracy=41.6
# Epoch  2, CIFAR-10 Batch 4:  Loss=3.698 accuracy=41.6
# Epoch  2, CIFAR-10 Batch 5:  Loss=2.962 accuracy=40.0
# Epoch  3, CIFAR-10 Batch 1:  Loss=2.016 accuracy=41.3
# Epoch  3, CIFAR-10 Batch 2:  Loss=1.490 accuracy=42.5
# Epoch  3, CIFAR-10 Batch 3:  Loss=1.359 accuracy=43.9
# Epoch  3, CIFAR-10 Batch 4:  Loss=1.380 accuracy=47.3
# Epoch  3, CIFAR-10 Batch 5:  Loss=1.421 accuracy=48.9
# Epoch  4, CIFAR-10 Batch 1:  Loss=1.446 accuracy=49.2
# Epoch  4, CIFAR-10 Batch 2:  Loss=1.406 accuracy=49.2
# Epoch  4, CIFAR-10 Batch 3:  Loss=1.269 accuracy=48.9
# Epoch  4, CIFAR-10 Batch 4:  Loss=1.330 accuracy=48.4
# Epoch  4, CIFAR-10 Batch 5:  Loss=1.340 accuracy=50.4
# Epoch  5, CIFAR-10 Batch 1:  Loss=1.388 accuracy=50.7
# Epoch  5, CIFAR-10 Batch 2:  Loss=1.337 accuracy=49.9
# Epoch  5, CIFAR-10 Batch 3:  Loss=1.269 accuracy=49.5
# Epoch  5, CIFAR-10 Batch 4:  Loss=1.289 accuracy=49.1
# Epoch  5, CIFAR-10 Batch 5:  Loss=1.300 accuracy=51.4
# Epoch  6, CIFAR-10 Batch 1:  Loss=1.362 accuracy=51.6
# Epoch  6, CIFAR-10 Batch 2:  Loss=1.298 accuracy=50.6
# Epoch  6, CIFAR-10 Batch 3:  Loss=1.247 accuracy=52.6
# Epoch  6, CIFAR-10 Batch 4:  Loss=1.209 accuracy=51.9
# Epoch  6, CIFAR-10 Batch 5:  Loss=1.287 accuracy=52.0
# Epoch  7, CIFAR-10 Batch 1:  Loss=1.367 accuracy=52.0
# Epoch  7, CIFAR-10 Batch 2:  Loss=1.248 accuracy=52.5
# Epoch  7, CIFAR-10 Batch 3:  Loss=1.210 accuracy=51.6
# Epoch  7, CIFAR-10 Batch 4:  Loss=1.221 accuracy=52.5
# Epoch  7, CIFAR-10 Batch 5:  Loss=1.249 accuracy=53.3
# Epoch  8, CIFAR-10 Batch 1:  Loss=1.308 accuracy=53.5
# Epoch  8, CIFAR-10 Batch 2:  Loss=1.234 accuracy=53.2
# Epoch  8, CIFAR-10 Batch 3:  Loss=1.167 accuracy=53.3
# Epoch  8, CIFAR-10 Batch 4:  Loss=1.155 accuracy=53.6
# Epoch  8, CIFAR-10 Batch 5:  Loss=1.213 accuracy=54.5
# Epoch  9, CIFAR-10 Batch 1:  Loss=1.303 accuracy=54.9
# Epoch  9, CIFAR-10 Batch 2:  Loss=1.175 accuracy=54.4
# Epoch  9, CIFAR-10 Batch 3:  Loss=1.107 accuracy=54.0
# Epoch  9, CIFAR-10 Batch 4:  Loss=1.116 accuracy=54.1
# Epoch  9, CIFAR-10 Batch 5:  Loss=1.170 accuracy=55.6
# Epoch 10, CIFAR-10 Batch 1:  Loss=1.243 accuracy=56.0
# Epoch 10, CIFAR-10 Batch 2:  Loss=1.142 accuracy=55.8
# Epoch 10, CIFAR-10 Batch 3:  Loss=1.096 accuracy=55.3
# Epoch 10, CIFAR-10 Batch 4:  Loss=1.082 accuracy=56.3
# Epoch 10, CIFAR-10 Batch 5:  Loss=1.154 accuracy=57.1
# Epoch 11, CIFAR-10 Batch 1:  Loss=1.212 accuracy=57.2
# Epoch 11, CIFAR-10 Batch 2:  Loss=1.126 accuracy=55.1
# Epoch 11, CIFAR-10 Batch 3:  Loss=1.056 accuracy=57.4
# Epoch 11, CIFAR-10 Batch 4:  Loss=1.056 accuracy=55.8
# Epoch 11, CIFAR-10 Batch 5:  Loss=1.145 accuracy=58.2
# Epoch 12, CIFAR-10 Batch 1:  Loss=1.210 accuracy=58.3
# Epoch 12, CIFAR-10 Batch 2:  Loss=1.157 accuracy=56.2
# Epoch 12, CIFAR-10 Batch 3:  Loss=1.031 accuracy=56.9
# Epoch 12, CIFAR-10 Batch 4:  Loss=1.034 accuracy=57.8
# Epoch 12, CIFAR-10 Batch 5:  Loss=1.089 accuracy=57.1
# Epoch 13, CIFAR-10 Batch 1:  Loss=1.159 accuracy=57.6
# Epoch 13, CIFAR-10 Batch 2:  Loss=1.061 accuracy=56.9
# Epoch 13, CIFAR-10 Batch 3:  Loss=0.988 accuracy=58.3
# Epoch 13, CIFAR-10 Batch 4:  Loss=0.983 accuracy=58.0
# Epoch 13, CIFAR-10 Batch 5:  Loss=1.065 accuracy=58.4
# Epoch 14, CIFAR-10 Batch 1:  Loss=1.094 accuracy=59.7
# Epoch 14, CIFAR-10 Batch 2:  Loss=1.031 accuracy=59.4
# Epoch 14, CIFAR-10 Batch 3:  Loss=0.972 accuracy=59.2
# Epoch 14, CIFAR-10 Batch 4:  Loss=0.966 accuracy=58.4
# Epoch 14, CIFAR-10 Batch 5:  Loss=1.081 accuracy=57.2
# Epoch 15, CIFAR-10 Batch 1:  Loss=1.108 accuracy=59.1
# Epoch 15, CIFAR-10 Batch 2:  Loss=1.037 accuracy=60.1
# Epoch 15, CIFAR-10 Batch 3:  Loss=0.935 accuracy=59.9
# Epoch 15, CIFAR-10 Batch 4:  Loss=0.971 accuracy=59.8
# Epoch 15, CIFAR-10 Batch 5:  Loss=1.014 accuracy=59.7
# Epoch 16, CIFAR-10 Batch 1:  Loss=1.045 accuracy=60.5
# Epoch 16, CIFAR-10 Batch 2:  Loss=0.986 accuracy=59.6
# Epoch 16, CIFAR-10 Batch 3:  Loss=0.951 accuracy=59.1
# Epoch 16, CIFAR-10 Batch 4:  Loss=0.912 accuracy=60.8
# Epoch 16, CIFAR-10 Batch 5:  Loss=1.031 accuracy=58.4
# Epoch 17, CIFAR-10 Batch 1:  Loss=1.060 accuracy=59.8
# Epoch 17, CIFAR-10 Batch 2:  Loss=0.971 accuracy=61.1
# Epoch 17, CIFAR-10 Batch 3:  Loss=0.930 accuracy=59.8
# Epoch 17, CIFAR-10 Batch 4:  Loss=0.875 accuracy=60.6
# Epoch 17, CIFAR-10 Batch 5:  Loss=0.954 accuracy=60.9
# Epoch 18, CIFAR-10 Batch 1:  Loss=0.986 accuracy=62.2
# Epoch 18, CIFAR-10 Batch 2:  Loss=0.911 accuracy=61.9
# Epoch 18, CIFAR-10 Batch 3:  Loss=0.886 accuracy=60.5
# Epoch 18, CIFAR-10 Batch 4:  Loss=0.887 accuracy=60.6
# Epoch 18, CIFAR-10 Batch 5:  Loss=0.929 accuracy=60.5
# Epoch 19, CIFAR-10 Batch 1:  Loss=0.991 accuracy=62.1
# Epoch 19, CIFAR-10 Batch 2:  Loss=0.917 accuracy=61.0
# Epoch 19, CIFAR-10 Batch 3:  Loss=0.852 accuracy=62.0
# Epoch 19, CIFAR-10 Batch 4:  Loss=0.810 accuracy=61.8
# Epoch 19, CIFAR-10 Batch 5:  Loss=0.874 accuracy=62.0
# Epoch 20, CIFAR-10 Batch 1:  Loss=0.946 accuracy=62.9
# Epoch 20, CIFAR-10 Batch 2:  Loss=0.888 accuracy=63.2
# Epoch 20, CIFAR-10 Batch 3:  Loss=0.822 accuracy=62.3
# Epoch 20, CIFAR-10 Batch 4:  Loss=0.827 accuracy=62.0
# Epoch 20, CIFAR-10 Batch 5:  Loss=0.873 accuracy=61.4
# Epoch 21, CIFAR-10 Batch 1:  Loss=0.941 accuracy=64.1
# Epoch 21, CIFAR-10 Batch 2:  Loss=0.903 accuracy=61.1
# Epoch 21, CIFAR-10 Batch 3:  Loss=0.803 accuracy=62.2
# Epoch 21, CIFAR-10 Batch 4:  Loss=0.835 accuracy=62.1
# Epoch 21, CIFAR-10 Batch 5:  Loss=0.827 accuracy=63.3
# Epoch 22, CIFAR-10 Batch 1:  Loss=0.954 accuracy=62.9
# Epoch 22, CIFAR-10 Batch 2:  Loss=0.857 accuracy=63.4
# Epoch 22, CIFAR-10 Batch 3:  Loss=0.757 accuracy=63.6
# Epoch 22, CIFAR-10 Batch 4:  Loss=0.752 accuracy=64.2
# Epoch 22, CIFAR-10 Batch 5:  Loss=0.778 accuracy=63.1
# Epoch 23, CIFAR-10 Batch 1:  Loss=0.916 accuracy=64.4
# Epoch 23, CIFAR-10 Batch 2:  Loss=0.844 accuracy=64.1
# Epoch 23, CIFAR-10 Batch 3:  Loss=0.733 accuracy=64.1
# Epoch 23, CIFAR-10 Batch 4:  Loss=0.763 accuracy=63.7
# Epoch 23, CIFAR-10 Batch 5:  Loss=0.744 accuracy=63.7
# Epoch 24, CIFAR-10 Batch 1:  Loss=0.872 accuracy=64.8
# Epoch 24, CIFAR-10 Batch 2:  Loss=0.863 accuracy=63.2
# Epoch 24, CIFAR-10 Batch 3:  Loss=0.753 accuracy=64.1
# Epoch 24, CIFAR-10 Batch 4:  Loss=0.751 accuracy=63.5
# Epoch 24, CIFAR-10 Batch 5:  Loss=0.730 accuracy=64.8
# Epoch 25, CIFAR-10 Batch 1:  Loss=0.845 accuracy=65.5
# Epoch 25, CIFAR-10 Batch 2:  Loss=0.802 accuracy=63.9
# Epoch 25, CIFAR-10 Batch 3:  Loss=0.719 accuracy=63.3
# Epoch 25, CIFAR-10 Batch 4:  Loss=0.679 accuracy=65.8
# Epoch 25, CIFAR-10 Batch 5:  Loss=0.738 accuracy=65.0
# Epoch 26, CIFAR-10 Batch 1:  Loss=0.793 accuracy=65.8
# Epoch 26, CIFAR-10 Batch 2:  Loss=0.762 accuracy=64.6
# Epoch 26, CIFAR-10 Batch 3:  Loss=0.720 accuracy=63.9
# Epoch 26, CIFAR-10 Batch 4:  Loss=0.720 accuracy=64.9
# Epoch 26, CIFAR-10 Batch 5:  Loss=0.719 accuracy=65.0
# Epoch 27, CIFAR-10 Batch 1:  Loss=0.785 accuracy=66.1
# Epoch 27, CIFAR-10 Batch 2:  Loss=0.763 accuracy=64.9
# Epoch 27, CIFAR-10 Batch 3:  Loss=0.662 accuracy=65.0
# Epoch 27, CIFAR-10 Batch 4:  Loss=0.659 accuracy=65.9
# Epoch 27, CIFAR-10 Batch 5:  Loss=0.681 accuracy=65.8
# Epoch 28, CIFAR-10 Batch 1:  Loss=0.768 accuracy=66.6
# Epoch 28, CIFAR-10 Batch 2:  Loss=0.723 accuracy=66.6
# Epoch 28, CIFAR-10 Batch 3:  Loss=0.637 accuracy=65.8
# Epoch 28, CIFAR-10 Batch 4:  Loss=0.651 accuracy=66.8
# Epoch 28, CIFAR-10 Batch 5:  Loss=0.639 accuracy=67.0
# Epoch 29, CIFAR-10 Batch 1:  Loss=0.767 accuracy=66.8
# Epoch 29, CIFAR-10 Batch 2:  Loss=0.777 accuracy=64.2
# Epoch 29, CIFAR-10 Batch 3:  Loss=0.635 accuracy=66.4
# Epoch 29, CIFAR-10 Batch 4:  Loss=0.633 accuracy=66.3
# Epoch 29, CIFAR-10 Batch 5:  Loss=0.619 accuracy=66.4
# Epoch 30, CIFAR-10 Batch 1:  Loss=0.745 accuracy=65.7
# Epoch 30, CIFAR-10 Batch 2:  Loss=0.690 accuracy=66.5
# Epoch 30, CIFAR-10 Batch 3:  Loss=0.664 accuracy=65.9
# Epoch 30, CIFAR-10 Batch 4:  Loss=0.603 accuracy=66.5
# Epoch 30, CIFAR-10 Batch 5:  Loss=0.597 accuracy=67.8
# Epoch 31, CIFAR-10 Batch 1:  Loss=0.711 accuracy=66.7
# Epoch 31, CIFAR-10 Batch 2:  Loss=0.699 accuracy=67.0
# Epoch 31, CIFAR-10 Batch 3:  Loss=0.597 accuracy=66.3
# Epoch 31, CIFAR-10 Batch 4:  Loss=0.613 accuracy=65.1
# Epoch 31, CIFAR-10 Batch 5:  Loss=0.598 accuracy=66.7
# Epoch 32, CIFAR-10 Batch 1:  Loss=0.699 accuracy=67.6
# Epoch 32, CIFAR-10 Batch 2:  Loss=0.683 accuracy=67.1
# Epoch 32, CIFAR-10 Batch 3:  Loss=0.619 accuracy=66.6
# Epoch 32, CIFAR-10 Batch 4:  Loss=0.578 accuracy=67.7
# Epoch 32, CIFAR-10 Batch 5:  Loss=0.585 accuracy=67.7
# Epoch 33, CIFAR-10 Batch 1:  Loss=0.677 accuracy=67.3
# Epoch 33, CIFAR-10 Batch 2:  Loss=0.708 accuracy=66.5
# Epoch 33, CIFAR-10 Batch 3:  Loss=0.603 accuracy=67.1
# Epoch 33, CIFAR-10 Batch 4:  Loss=0.558 accuracy=67.6
# Epoch 33, CIFAR-10 Batch 5:  Loss=0.536 accuracy=68.0
# Epoch 34, CIFAR-10 Batch 1:  Loss=0.684 accuracy=67.5
# Epoch 34, CIFAR-10 Batch 2:  Loss=0.643 accuracy=66.4
# Epoch 34, CIFAR-10 Batch 3:  Loss=0.565 accuracy=67.8
# Epoch 34, CIFAR-10 Batch 4:  Loss=0.532 accuracy=67.0
# Epoch 34, CIFAR-10 Batch 5:  Loss=0.522 accuracy=67.6
# Epoch 35, CIFAR-10 Batch 1:  Loss=0.670 accuracy=67.4
# Epoch 35, CIFAR-10 Batch 2:  Loss=0.644 accuracy=66.4
# Epoch 35, CIFAR-10 Batch 3:  Loss=0.551 accuracy=67.9
# Epoch 35, CIFAR-10 Batch 4:  Loss=0.517 accuracy=67.6
# Epoch 35, CIFAR-10 Batch 5:  Loss=0.528 accuracy=68.6
# Epoch 36, CIFAR-10 Batch 1:  Loss=0.669 accuracy=68.3
# Epoch 36, CIFAR-10 Batch 2:  Loss=0.634 accuracy=68.1
# Epoch 36, CIFAR-10 Batch 3:  Loss=0.538 accuracy=68.5
# Epoch 36, CIFAR-10 Batch 4:  Loss=0.497 accuracy=67.3
# Epoch 36, CIFAR-10 Batch 5:  Loss=0.494 accuracy=68.4
# Epoch 37, CIFAR-10 Batch 1:  Loss=0.635 accuracy=68.2
# Epoch 37, CIFAR-10 Batch 2:  Loss=0.606 accuracy=67.8
# Epoch 37, CIFAR-10 Batch 3:  Loss=0.519 accuracy=67.9
# Epoch 37, CIFAR-10 Batch 4:  Loss=0.495 accuracy=67.9
# Epoch 37, CIFAR-10 Batch 5:  Loss=0.508 accuracy=68.0
# Epoch 38, CIFAR-10 Batch 1:  Loss=0.690 accuracy=67.2
# Epoch 38, CIFAR-10 Batch 2:  Loss=0.596 accuracy=67.3
# Epoch 38, CIFAR-10 Batch 3:  Loss=0.518 accuracy=68.7
# Epoch 38, CIFAR-10 Batch 4:  Loss=0.465 accuracy=68.3
# Epoch 38, CIFAR-10 Batch 5:  Loss=0.490 accuracy=68.4
# Epoch 39, CIFAR-10 Batch 1:  Loss=0.592 accuracy=68.8
# Epoch 39, CIFAR-10 Batch 2:  Loss=0.551 accuracy=67.9
# Epoch 39, CIFAR-10 Batch 3:  Loss=0.522 accuracy=68.3
# Epoch 39, CIFAR-10 Batch 4:  Loss=0.475 accuracy=68.1
# Epoch 39, CIFAR-10 Batch 5:  Loss=0.457 accuracy=68.3
# Epoch 40, CIFAR-10 Batch 1:  Loss=0.594 accuracy=68.9
# Epoch 40, CIFAR-10 Batch 2:  Loss=0.533 accuracy=69.1
# Epoch 40, CIFAR-10 Batch 3:  Loss=0.506 accuracy=68.4
# Epoch 40, CIFAR-10 Batch 4:  Loss=0.447 accuracy=68.1
# Epoch 40, CIFAR-10 Batch 5:  Loss=0.447 accuracy=68.7
# Epoch 41, CIFAR-10 Batch 1:  Loss=0.542 accuracy=69.7
# Epoch 41, CIFAR-10 Batch 2:  Loss=0.537 accuracy=68.8
# Epoch 41, CIFAR-10 Batch 3:  Loss=0.483 accuracy=68.4
# Epoch 41, CIFAR-10 Batch 4:  Loss=0.441 accuracy=68.4
# Epoch 41, CIFAR-10 Batch 5:  Loss=0.454 accuracy=68.4
# Epoch 42, CIFAR-10 Batch 1:  Loss=0.541 accuracy=70.1
# Epoch 42, CIFAR-10 Batch 2:  Loss=0.553 accuracy=67.2
# Epoch 42, CIFAR-10 Batch 3:  Loss=0.483 accuracy=68.7
# Epoch 42, CIFAR-10 Batch 4:  Loss=0.454 accuracy=68.0
# Epoch 42, CIFAR-10 Batch 5:  Loss=0.421 accuracy=68.9
# Epoch 43, CIFAR-10 Batch 1:  Loss=0.535 accuracy=69.3
# Epoch 43, CIFAR-10 Batch 2:  Loss=0.524 accuracy=69.1
# Epoch 43, CIFAR-10 Batch 3:  Loss=0.488 accuracy=68.7
# Epoch 43, CIFAR-10 Batch 4:  Loss=0.423 accuracy=69.4
# Epoch 43, CIFAR-10 Batch 5:  Loss=0.389 accuracy=69.5
# Epoch 44, CIFAR-10 Batch 1:  Loss=0.514 accuracy=69.1
# Epoch 44, CIFAR-10 Batch 2:  Loss=0.531 accuracy=68.5
# Epoch 44, CIFAR-10 Batch 3:  Loss=0.459 accuracy=68.3
# Epoch 44, CIFAR-10 Batch 4:  Loss=0.397 accuracy=68.9
# Epoch 44, CIFAR-10 Batch 5:  Loss=0.419 accuracy=69.0
# Epoch 45, CIFAR-10 Batch 1:  Loss=0.498 accuracy=68.6
# Epoch 45, CIFAR-10 Batch 2:  Loss=0.548 accuracy=66.7
# Epoch 45, CIFAR-10 Batch 3:  Loss=0.431 accuracy=69.1
# Epoch 45, CIFAR-10 Batch 4:  Loss=0.388 accuracy=69.1
# Epoch 45, CIFAR-10 Batch 5:  Loss=0.368 accuracy=69.4
# Epoch 46, CIFAR-10 Batch 1:  Loss=0.478 accuracy=68.7
# Epoch 46, CIFAR-10 Batch 2:  Loss=0.468 accuracy=69.4
# Epoch 46, CIFAR-10 Batch 3:  Loss=0.429 accuracy=68.4
# Epoch 46, CIFAR-10 Batch 4:  Loss=0.401 accuracy=68.7
# Epoch 46, CIFAR-10 Batch 5:  Loss=0.383 accuracy=68.9
# Epoch 47, CIFAR-10 Batch 1:  Loss=0.454 accuracy=70.1
# Epoch 47, CIFAR-10 Batch 2:  Loss=0.451 accuracy=68.4
# Epoch 47, CIFAR-10 Batch 3:  Loss=0.412 accuracy=69.2
# Epoch 47, CIFAR-10 Batch 4:  Loss=0.373 accuracy=69.5
# Epoch 47, CIFAR-10 Batch 5:  Loss=0.369 accuracy=69.3
# Epoch 48, CIFAR-10 Batch 1:  Loss=0.486 accuracy=69.5
# Epoch 48, CIFAR-10 Batch 2:  Loss=0.438 accuracy=69.5
# Epoch 48, CIFAR-10 Batch 3:  Loss=0.391 accuracy=69.1
# Epoch 48, CIFAR-10 Batch 4:  Loss=0.358 accuracy=69.3
# Epoch 48, CIFAR-10 Batch 5:  Loss=0.357 accuracy=70.1
# Epoch 49, CIFAR-10 Batch 1:  Loss=0.424 accuracy=69.5
# Epoch 49, CIFAR-10 Batch 2:  Loss=0.410 accuracy=69.8
# Epoch 49, CIFAR-10 Batch 3:  Loss=0.376 accuracy=69.5
# Epoch 49, CIFAR-10 Batch 4:  Loss=0.338 accuracy=69.7
# Epoch 49, CIFAR-10 Batch 5:  Loss=0.342 accuracy=69.4
# Epoch 50, CIFAR-10 Batch 1:  Loss=0.438 accuracy=68.2
# Epoch 50, CIFAR-10 Batch 2:  Loss=0.420 accuracy=69.6
# Epoch 50, CIFAR-10 Batch 3:  Loss=0.372 accuracy=69.6
# Epoch 50, CIFAR-10 Batch 4:  Loss=0.366 accuracy=68.5
# Epoch 50, CIFAR-10 Batch 5:  Loss=0.349 accuracy=68.8

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_training.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for train_feature_batch, train_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: train_feature_batch, loaded_y: train_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# INFO:tensorflow:Restoring parameters from ./image_classification
# Testing Accuracy: 0.6950769782066345

# %% [markdown]
# ## Why 50-80% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. That's because there are many more techniques that can be applied to your model and we recemmond that once you are done with this project, you explore!
#
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
